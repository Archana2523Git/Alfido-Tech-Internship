# %% [markdown]
# <a href="https://colab.research.google.com/github/Archana2523Git/Alfido-Tech-Internship/blob/main/Task-1/Pandas_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={'Name': ['Archana', 'Ester','John','Amith'],'Age':[20,2,19,22]}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
df.to_csv('data.csv',index=False)
df_csv=pd.read_csv('data.csv')
print(df_csv)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
df_csv.head()
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
df_csv.tail()
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
clean_df=df_csv.dropna()
print(clean_df)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
filled_df=df_csv.fillna(0)
print(filled_df)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
df_csv['Name']
# Out:
# 0    Archana
# 1      Ester
# 2       John
# 3      Amith
# Name: Name, dtype: object

# %%
df_csv.iloc[2]
# Out:
# Name    John
# Age       19
# Name: 2, dtype: object

# %%
df_csv.loc[df_csv['Name']=='Archana']
# Out:
#       Name  Age
# 0  Archana   20

# %%
df_csv[df_csv['Age']>18]
# Out:
#       Name  Age
# 0  Archana   20
# 2     John   19
# 3    Amith   22

# %%
df_csv.groupby('Age').count()
# Out:
#      Name
# Age
# 2       1
# 19      1
# 20      1
# 22      1

# %%
df2=pd.DataFrame({'Name':['Archana'],'City':['Hyderabad']})
merged_df=pd.merge(df_csv,df2,on='Name')
print(merged_df)
# Out:
#       Name  Age       City
# 0  Archana   20  Hyderabad

# %%
print(df_csv)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22

# %%
df_csv.to_csv('output.csv',index=False)
exported_data=pd.read_csv('output.csv')
print(exported_data)
# Out:
#       Name  Age
# 0  Archana   20
# 1    Ester    2
# 2     John   19
# 3    Amith   22
